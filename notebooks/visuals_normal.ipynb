# %%
import random
import pandas as pd
import networkx as nx
import markov_clustering as mc
import matplotlib.pyplot as plt

# %%
import numpy as np
import networkx as nx
from typing import Dict, List, Tuple, Union
from scipy import sparse

import warnings
warnings.simplefilter("ignore")

# %%
def draw_plot(file_num, dataset, z):
    '''
    Plot files for each of the datasets
    '''
    # Load the file and stuff as per the dataset
    edge_file = f'./sampling_comparison/{dataset}_edges_{file_num}.parquet'
    label_file = f'./sampling_comparison/{dataset}_labels_{file_num}.parquet'
    
    # Load the files
    df_e = pd.read_parquet(edge_file)
    df_l = pd.read_parquet(label_file)
    print(df_l[df_l["label"] == 1])

    # Define the node colors
    color_map = []
    for _, row in df_l.iterrows():
        if int(row["label"]) == 1:
            color_map.append("red")
        else:
            color_map.append("blue")

    # Plot the graph
    
    G = nx.Graph()
    for index, row in df_e.iterrows():
        G.add_edge(row['from'], row['to'])

    print(f"Total edges : {G.number_of_edges()}")
    plt.subplot(1, 2, z)
    nx.draw(G, with_labels=False, node_size=60, node_color=color_map)

# %%
p=2
plt.figure(figsize=(10, 6))
draw_plot(p, "bfs", 1)
draw_plot(p, "bf", 2)
plt.show()
# Out:
#                                                 txid  label  node
# 6  5abd2223cd58f8f913f85d1220a2ca172f8fc2b98e6eb4...      1    68
# Total edges : 150
#                                                 txid  label  node
# 3  5abd2223cd58f8f913f85d1220a2ca172f8fc2b98e6eb4...      1     1
# Total edges : 150

# %%
p=5
plt.figure(figsize=(10, 6))
draw_plot(p, "bfs", 1)
draw_plot(p, "bf", 2)
plt.show()
# Out:
#                                                   txid  label  node
# 329  3110cfca4fd6066fe456e1d4eee18f72a07bfe16d9accc...      1   139
# 81   99087006063d24e9320d90f5d00c3edce975bfce713e2f...      1   226
# 217  37035aeb4f44f5caa9f7995a2e2d82e263da9b58e900d1...      1   261
# Total edges : 452
#                                                   txid  label  node
# 224  3110cfca4fd6066fe456e1d4eee18f72a07bfe16d9accc...      1   195
# 41   99087006063d24e9320d90f5d00c3edce975bfce713e2f...      1   282
# Total edges : 301

# %%
p=7
plt.figure(figsize=(10, 6))
draw_plot(p, "bfs", 1)
draw_plot(p, "bf", 2)
plt.show()
# Out:
#                                                  txid  label  node
# 17  2088b03cc7545dd482abfbad1bb66804b9fd9bea52e865...      1    11
# Total edges : 81
#                                                  txid  label  node
# 17  2088b03cc7545dd482abfbad1bb66804b9fd9bea52e865...      1    11
# Total edges : 81

# %%
p=9
plt.figure(figsize=(10, 6))
draw_plot(p, "bfs", 1)
draw_plot(p, "bf", 2)
plt.show()
# Out:
#                                                  txid  label  node
# 28  875d4ec577898474b7695a7067407b5f6b54e80ecc5a3f...      1   147
# Total edges : 150
#                                                 txid  label  node
# 2  875d4ec577898474b7695a7067407b5f6b54e80ecc5a3f...      1    10
# Total edges : 12

# %%
p=10
plt.figure(figsize=(10, 6))
draw_plot(p, "bfs", 1)
draw_plot(p, "bf", 2)
plt.show()
# Out:
#                                                 txid  label  node
# 1  aa3ba3f85e55b194c76fa468acef18a21ca5fb84fbdad9...      1     1
# Total edges : 1
#                                                 txid  label  node
# 1  aa3ba3f85e55b194c76fa468acef18a21ca5fb84fbdad9...      1     1
# Total edges : 1

# %%
p=11
plt.figure(figsize=(10, 6))
draw_plot(p, "bfs", 1)
draw_plot(p, "bf", 2)
plt.show()
# Out:
#                                                  txid  label  node
# 50  25b89b8ec622ee2eb437fcd73d2bad16b83cd24ac64fa2...      1    65
# Total edges : 150
#                                                  txid  label  node
# 41  25b89b8ec622ee2eb437fcd73d2bad16b83cd24ac64fa2...      1    72
# Total edges : 153

# %%
p=13
plt.figure(figsize=(10, 6))
draw_plot(p, "bfs", 1)
draw_plot(p, "bf", 2)
plt.show()
# Out:
#                                                  txid  label  node
# 54  d40756173d99240611bdaae2485363bce194c7a7a5224f...      1   150
# Total edges : 150
#                                                  txid  label  node
# 54  d40756173d99240611bdaae2485363bce194c7a7a5224f...      1   150
# Total edges : 150

# %%
p=17
plt.figure(figsize=(10, 6))
draw_plot(p, "bfs", 1)
draw_plot(p, "bf", 2)
plt.show()
# Out:
#                                                 txid  label  node
# 1  14ef67a3daa7327c712458cdb72e55b3e92e3aa0499ce0...      1     1
# Total edges : 3
#                                                 txid  label  node
# 0  14ef67a3daa7327c712458cdb72e55b3e92e3aa0499ce0...      1     1
# Total edges : 2

# %%
p=22
plt.figure(figsize=(10, 6))
draw_plot(p, "bfs", 1)
draw_plot(p, "bf", 2)
plt.show()
# Out:
#                                                 txid  label  node
# 1  e74b41b174b5a87e4ee907a9d3d1920b300cbd8c890190...      1     0
# Total edges : 2
#                                                 txid  label  node
# 1  e74b41b174b5a87e4ee907a9d3d1920b300cbd8c890190...      1     0
# Total edges : 2

# %%
p=26
plt.figure(figsize=(10, 6))
draw_plot(p, "bfs", 1)
draw_plot(p, "bf", 2)
plt.show()
# Out:
#                                                  txid  label  node
# 36  c2aedcec909ed91063ebd136de3eea19eccd643229cdf4...      1    50
# Total edges : 71
#                                                  txid  label  node
# 36  c2aedcec909ed91063ebd136de3eea19eccd643229cdf4...      1    50
# Total edges : 71

# %%
p=28
plt.figure(figsize=(10, 6))
draw_plot(p, "bfs", 1)
draw_plot(p, "bf", 2)
plt.show()
# Out:
#                                                  txid  label  node
# 80  3c6a9afc80daa9b85deff91ae043d701b3d3590ef8f6f4...      1   130
# Total edges : 150
#                                                 txid  label  node
# 1  3c6a9afc80daa9b85deff91ae043d701b3d3590ef8f6f4...      1     1
# Total edges : 2
